# %%
import pandas as pd

# %%
df = pd.read_csv('pl-4c3db6fa-9c95-4135-a713-37992a60be02_eeg.csv')

# %%
x = df['timestamp']
y = df['ch1']

# %%
# Plot the data
import matplotlib.pyplot as plt
plt.plot(x, y)
# plot in the middle of x a vertical line
plt.axvline(x=x.iloc[len(x)//2], color='r', linestyle='--')
